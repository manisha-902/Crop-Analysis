# %% [markdown]
# # PART : A Data processing

# %% [markdown]
# # STEP 1: Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # STEP2: Import dataset

# %%
dataset=pd.read_csv('datafile.csv')

# %%
dataset
# Out:
#             Crop               Production 2016-17  Production 2017-18  \
# 0            Total Foodgrains               158.8               168.6
# 1                        Rice               200.8               207.9
# 2                       Wheat               131.6               136.4
# 3                       Jowar               124.3               137.8
# 4                       Bajra               136.4               161.5
# 5                       Maize               198.8               249.6
# 6                        Ragi                56.1                83.6
# 7               Small millets                53.9                61.9
# 8                      Barley                88.1                79.3
# 9              Coarse Cereals               138.5               166.4
# 10                    Cereals               164.1               174.6
# 11                       Gram               140.6               127.6
# ...

# %% [markdown]
# # STEP 3: To create feature matrix(X) and dependent variable vector(Y)

# %%
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,-1].values

# %%
X
# Out:
# array([['Total Foodgrains', 158.8, 168.6, 171.3, 159.4, 178.9, 128.5,
#         128.8, 127.6, 126.0, 131.7, 123.6, 130.9, 134.3, 126.5],
#        ['Rice', 200.8, 207.9, 213.3, 191.6, 206.4, 168.5, 168.9, 175.1,
#         161.2, 164.8, 119.2, 123.1, 121.8, 118.9],
#        ['Wheat', 131.6, 136.4, 140.1, 140.3, 150.8, 115.0, 115.2, 114.0,
#         116.9, 119.5, 114.4, 118.4, 122.8, 120.0],
#        ['Jowar', 124.3, 137.8, 126.0, 116.5, 121.8, 120.7, 110.6, 107.3,
#         111.0, 105.2, 103.0, 124.6, 117.4, 105.0],
#        ['Bajra', 136.4, 161.5, 143.9, 105.4, 167.9, 94.5, 95.1, 87.0,
#         88.5, 95.6, 144.3, 169.7, 165.4, 119.0],
#        ['Maize', 198.8, 249.6, 259.8, 220.1, 286.0, 156.1, 160.5, 161.6,
#         163.4, 169.1, 127.3, 155.5, 160.7, 134.7],
#        ['Ragi', 56.1, 83.6, 79.3, 73.4, 85.2, 60.2, 70.9, 70.6, 64.8,
#         65.8, 93.2, 117.9, 112.2, 113.2],
#        ['Small millets', 53.9, 61.9, 50.0, 42.9, 82.0, 50.9, 52.3, 45.6,
# ...

# %%
Y
# Out:
# array([ 135.9,  125.2,  126.3,  115.8,  175.8,  169.1,  129.6,  182.4,
#         138.9,  169.2,  141.1,  121.7,   98.1,  129. ,  120.4,  123.4,
#         126.1,  151.2,  151.9,  140.2,  123.9,  171.9,  116.7,   96.9,
#         114. ,  141.9,  152. ,   80.8,  181.5,  168.6,  207.9,  211.5,
#         112. ,  211.8,  230.9,   95.8,  128.5,  140.9, 1310.8,  103.4,
#         185.5,  148.8,  136.4,  105.1,  196.1,  199.9,  130.1,  145.7,
#         145.2,  154.8,  109.6,  130. ,  165.9,  106.7,  118.6])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Crop                55 non-null     object
#  1   Production 2016-17  55 non-null     float64
#  2   Production 2017-18  55 non-null     float64
#  3   Production 2018-19  55 non-null     float64
#  4   Production 2019-20  55 non-null     float64
#  5   Production 2020-21  55 non-null     float64
#  6   Area 2016-17        55 non-null     float64
#  7   Area 2017-18        55 non-null     float64
#  8   Area 2018-19        55 non-null     float64
#  9   Area 2019-20        55 non-null     float64
#  10  Area 2020-21        55 non-null     float64
#  11  Yield 2016-17       55 non-null     float64
#  12  Yield 2017-18       55 non-null     float64
#  13  Yield 2018-19       55 non-null     float64
#  14  Yield 2019-20       55 non-null     float64
# ...

# %% [markdown]
# # Graphical representation

# %%
plt.plot(dataset['Production 2016-17'],marker='o',markerfacecolor='yellow',markersize=7)
plt.xlabel('crop')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %%
plt.plot(dataset['Area 2016-17'],marker='o',markerfacecolor='yellow',markersize=7)
plt.xlabel('crop')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %%
plt.plot(dataset['Yield 2016-17'],marker='o',markerfacecolor='yellow',markersize=7)
plt.xlabel('crop')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %%
plt.plot(dataset['Production 2016-17'],marker='o',markerfacecolor='yellow',markersize=7)
plt.plot(dataset['Area 2016-17'],marker='o',markerfacecolor='blue',markersize=7)
plt.plot(dataset['Yield 2016-17'],marker='o',markerfacecolor='red',markersize=7)
plt.xlabel('crop')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %%
plt.plot(dataset['Production 2018-19'],marker='o',markerfacecolor='yellow',markersize=7)
plt.plot(dataset['Area 2018-19'],marker='o',markerfacecolor='blue',markersize=7)
plt.plot(dataset['Yield 2018-19'],marker='o',markerfacecolor='red',markersize=7)
plt.xlabel('crop')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %%
plt.plot(dataset['Production 2019-20'],marker='o',markerfacecolor='yellow',markersize=7)
plt.plot(dataset['Area 2019-20'],marker='o',markerfacecolor='blue',markersize=7)
plt.plot(dataset['Yield 2019-20'],marker='o',markerfacecolor='red',markersize=7)
plt.xlabel('crop')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %% [markdown]
# # STEP 4: Replacing the missing data

# %% [markdown]
# # STEP 5: Encoding

# %% [markdown]
# # Feature Matrix using OneHotEncoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0])],remainder='passthrough')
dataset = np.array(ct.fit_transform(dataset))

# %%
X
# Out:
# array([['Total Foodgrains', 158.8, 168.6, 171.3, 159.4, 178.9, 128.5,
#         128.8, 127.6, 126.0, 131.7, 123.6, 130.9, 134.3, 126.5],
#        ['Rice', 200.8, 207.9, 213.3, 191.6, 206.4, 168.5, 168.9, 175.1,
#         161.2, 164.8, 119.2, 123.1, 121.8, 118.9],
#        ['Wheat', 131.6, 136.4, 140.1, 140.3, 150.8, 115.0, 115.2, 114.0,
#         116.9, 119.5, 114.4, 118.4, 122.8, 120.0],
#        ['Jowar', 124.3, 137.8, 126.0, 116.5, 121.8, 120.7, 110.6, 107.3,
#         111.0, 105.2, 103.0, 124.6, 117.4, 105.0],
#        ['Bajra', 136.4, 161.5, 143.9, 105.4, 167.9, 94.5, 95.1, 87.0,
#         88.5, 95.6, 144.3, 169.7, 165.4, 119.0],
#        ['Maize', 198.8, 249.6, 259.8, 220.1, 286.0, 156.1, 160.5, 161.6,
#         163.4, 169.1, 127.3, 155.5, 160.7, 134.7],
#        ['Ragi', 56.1, 83.6, 79.3, 73.4, 85.2, 60.2, 70.9, 70.6, 64.8,
#         65.8, 93.2, 117.9, 112.2, 113.2],
#        ['Small millets', 53.9, 61.9, 50.0, 42.9, 82.0, 50.9, 52.3, 45.6,
# ...

# %% [markdown]
# # STEP 6: Spliting the data set into training data set and testing data set

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
Xtrain
# Out:
# array([['Coffee ', 138.0, 139.8, 139.9, 154.5, 161.1, 117.9, 119.8,
#         121.9, 123.7, 125.4, 117.0, 116.7, 114.8, 125.0],
#        ['Cereals', 164.1, 174.6, 177.7, 164.4, 183.1, 130.0, 129.9,
#         130.3, 126.8, 129.8, 126.3, 134.4, 136.4, 129.7],
#        ['Jowar', 124.3, 137.8, 126.0, 116.5, 121.8, 120.7, 110.6, 107.3,
#         111.0, 105.2, 103.0, 124.6, 117.4, 105.0],
#        ['Dry chilies ', 163.5, 170.8, 167.1, 158.3, 160.9, 83.6, 88.3,
#         85.4, 84.0, 86.8, 195.5, 193.4, 195.8, 188.4],
#        ['Coriander', 126.4, 167.9, 131.3, 128.5, 261.3, 79.1, 94.8, 97.9,
#         88.8, 130.7, 159.8, 177.2, 134.1, 144.7],
#        ['Onion', 240.5, 247.3, 367.1, 329.1, 409.1, 207.7, 208.4, 246.8,
#         223.6, 314.7, 115.8, 118.7, 148.8, 147.1],
#        ['Sunflower', 161.3, 192.3, 152.2, 111.8, 85.6, 175.0, 154.5,
#         146.5, 119.3, 75.1, 92.2, 124.5, 103.9, 93.7],
#        ['Cardamom ', 159.2, 135.8, 157.1, 159.2, 162.2, 93.4, 77.8, 87.5,
# ...

# %%
Ytest
# Out:
# array([207.9, 126.3, 152. , 106.7,  95.8, 211.5, 145.2, 148.8, 112. ,
#        140.2, 145.7])

# %% [markdown]
# # STEP 7: Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Xtrain[:, 1:] = sc.fit_transform(Xtrain[:, 1:])
Xtest[:, 1:] = sc.transform(Xtest[:, 1:])

# %% [markdown]
# # STEP B: Build classification model

# %% [markdown]
# # STEP1: Training the linear model

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(Xtrain[:, 1:],Ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# # STEP 2: Testing the linear model

# %%
Yestimated=LR.predict(Xtest[:, 1:])

# %%
Yestimated
# Out:
# array([211.88241944, 127.56919154, 150.268338  , 110.06385936,
#         97.54127662, 202.693835  , 146.68996349, 174.90730511,
#        125.7777585 , 145.68355039, 146.82523408])

# %%
Ytest
# Out:
# array([207.9, 126.3, 152. , 106.7,  95.8, 211.5, 145.2, 148.8, 112. ,
#        140.2, 145.7])

# %%
LR.coef_
# Out:
# array([  37.7649049 , -160.06636204,  -30.76758476,  -65.29955014,
#         208.44520103,  -11.23417075,   45.71144955,    9.35946808,
#           6.85329025,  -54.54543641,  -30.77788223,  109.7396092 ,
#          62.62191978,   46.24989679])

# %%
LR.intercept_
# Out:
# 169.5295454545454

# %%
print(LR.predict([[88.1, 83.6, 96.4, 105.3, 140.9, 88.8, 83.9, 94.2,
        107.1, 118.8, 99.1, 88.3, 102.4, 109.6]]))
# Out:
# [25737.60115007]
